# %% [markdown]
# # 关于strip()方法的相关笔记和心得
# **语法**：```strip('要清除的字符串')```
# ##格式化的原理
# * 从左边&右边开始,一个一个删除，直到碰到不在要清除的字符串中的字符

# %%
wb_adress = '  www.4399.com       '
print(wb_adress.strip('w. com'))
# Out:
# 4399
