# %% [markdown]
# # 纯python的解释器设置代码的最佳实践

# %% [markdown]
# **（.py开头的那行）**

# %% [markdown]
# ----

# %% [markdown]
# ## 开头的标准设置代码

# %%
#!/usr/bin/python3

# %% [markdown]
# ## 这段开始代码的目的：

# %% [markdown]
# 文件中的代码用什么**可执行程序**去运行

# %% [markdown]
# ## 大概的调用方式/作用机理

# %% [markdown]
#  python 安装的时候会在 windows 目录下放两个文件 py.exe 和 pyw.exe，然后文件类型指向这个这两个文件，可能是由这两个文件判断由哪个 python.exe 去执行脚本

# %% [markdown]
# ----

# %% [markdown]
# ## 更好的解释器代码实现

# %%
#!/usr/bin/env python3
print('Hello Python!')
# Out:
# Hello Python!

# %% [markdown]
# 可以防止用户不把python装在**默认路径**下,系统看到这一行的时候，首先会到 env(虚拟环境设置)设置里查找 python3 的安装路径，再调用对应路径下的**解释器程序**完成操作。
# #!/usr/bin/python3 相当于**写死**了 **python3** 路径

# %% [markdown]
# ----
